# %% [markdown]
# # Montreal EV Charging Stations Exploration
#
# Run the pipeline first, then use this notebook to explore the processed Parquet output.

# %%
import pandas as pd

df = pd.read_parquet('../data/processed/charging_stations.parquet')
df.head()

# %%
df.info()

# %%
df['charging_level'].value_counts(dropna=False)

# %%
df.groupby('site_name').size().sort_values(ascending=False).head(20)
